# %% [markdown]
# If you plan to work with tabular data (rows and columns) that mix text and numbers, you might prefer pandas, which handles CSV files more naturally.

# %%
import pandas as pd
df = pd.read_csv('Person.csv')
print(df)
# Out:
#   Name,Age,Amount
# 0    John,25,72.5
# 1   Alice,30,68.0
# 2  Silent,30,68.0
# 3   Noise,30,68.0
